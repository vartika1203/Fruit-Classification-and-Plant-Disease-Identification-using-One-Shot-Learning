# %%
# !nvidia-smi
# Out:
# Mon Nov 29 06:21:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import numpy as np
import pandas as pd
import os
import keras.metrics
import matplotlib.pyplot as plt
from imutils import paths
from sklearn.model_selection import train_test_split

# %%
test_dir =  '/content/drive/MyDrive/Major Project/Datasets/Phase 1-Fruit Detection/fruits-360/Test/'

# %%
fruits = []
fruits_image = []
for i in os.listdir(test_dir):
    for image_filename in os.listdir(test_dir + i):
        fruits.append(i) # name of the fruit 
        fruits_image.append(i + '/' + image_filename)

# %%
test_fruits = pd.DataFrame(fruits, columns=["Fruits"])
test_fruits["Fruits Image"] = fruits_image

# %%
test_fruits
# Out:
#                Fruits                 Fruits Image
# 0      Apple Golden 3  Apple Golden 3/r_33_100.jpg
# 1      Apple Golden 3  Apple Golden 3/r_67_100.jpg
# 2      Apple Golden 3    Apple Golden 3/39_100.jpg
# 3      Apple Golden 3  Apple Golden 3/r_94_100.jpg
# 4      Apple Golden 3    Apple Golden 3/32_100.jpg
# ...               ...                          ...
# 22683      Watermelon       Watermelon/263_100.jpg
# 22684      Watermelon      Watermelon/r_48_100.jpg
# 22685      Watermelon     Watermelon/r_107_100.jpg
# 22686      Watermelon      Watermelon/r_80_100.jpg
# 22687      Watermelon       Watermelon/132_100.jpg
#
# [22688 rows x 2 columns]

# %%
image_paths=[]
data_labels=[]

# %%
for i in range(len(test_fruits)):
  path=test_fruits['Fruits Image'][i]
  path=test_dir+path
  label=test_fruits['Fruits'][i]
  image_paths.append(path)
  data_labels.append(label)

# %%
df_test = pd.DataFrame({"Path":image_paths,"Class":data_labels})

# %%
df_test
# Out:
#                                                     Path           Class
# 0      /content/drive/MyDrive/Major Project/Datasets/...  Apple Golden 3
# 1      /content/drive/MyDrive/Major Project/Datasets/...  Apple Golden 3
# 2      /content/drive/MyDrive/Major Project/Datasets/...  Apple Golden 3
# 3      /content/drive/MyDrive/Major Project/Datasets/...  Apple Golden 3
# 4      /content/drive/MyDrive/Major Project/Datasets/...  Apple Golden 3
# ...                                                  ...             ...
# 22683  /content/drive/MyDrive/Major Project/Datasets/...      Watermelon
# 22684  /content/drive/MyDrive/Major Project/Datasets/...      Watermelon
# 22685  /content/drive/MyDrive/Major Project/Datasets/...      Watermelon
# 22686  /content/drive/MyDrive/Major Project/Datasets/...      Watermelon
# 22687  /content/drive/MyDrive/Major Project/Datasets/...      Watermelon
#
# [22688 rows x 2 columns]

# %%
from keras.models import load_model

trained_model = load_model("/content/drive/MyDrive/Major Project/Training Files/50-25-25/Models/vgg16-ep15.h5")

# %%
trained_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 100, 100, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 100, 100, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 50, 50, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 50, 50, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 50, 50, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 25, 25, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 25, 25, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 25, 25, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 12, 12, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 12, 12, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 12, 12, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 6, 6, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 131)               16899
#
# =================================================================
# Total params: 15,321,539
# Trainable params: 606,851
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
ts_data = ImageDataGenerator()
testing_df = ts_data.flow_from_dataframe(df_test, x_col = "Path",y_col = "Class", batch_size=1, target_size=(100, 100))
# Out:
# Found 22688 validated image filenames belonging to 131 classes.

# %%
trained_model.evaluate(testing_df)
# Out:
# 22688/22688 [==============================] - 5278s 233ms/step - loss: 0.3738 - accuracy: 0.9413 - precision: 0.9508 - recall: 0.9375 - auc: 0.9899 - tp: 21270.0000 - fp: 1100.0000 - tn: 2948340.0000 - fn: 1418.0000
# [0.373765230178833,
#  0.941290557384491,
#  0.9508270025253296,
#  0.9375,
#  0.9899157881736755,
#  21270.0,
#  1100.0,
#  2948340.0,
#  1418.0]
